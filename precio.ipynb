# %%
import requests
from pprint import pprint
'''
Separamos responsabilidades (buena practica)
- El bot queda como está
- Creamos un archivo nuevo solo para probar precios
'''

# URL de la api a consumir
URL = "https://api.bluelytics.com.ar/v2/latest"

response = requests.get(URL)
data = response.json()


dolar_mep = data["dolar"]["bolsa"]["value_avg"]
# Out:
# oficial {'value_avg': 1457.5, 'value_sell': 1485.0, 'value_buy': 1430.0}
# blue {'value_avg': 1490.0, 'value_sell': 1500.0, 'value_buy': 1480.0}
# oficial_euro {'value_avg': 1584.0, 'value_sell': 1614.0, 'value_buy': 1554.0}
# blue_euro {'value_avg': 1619.5, 'value_sell': 1630.0, 'value_buy': 1609.0}
# last_update 2025-12-16T18:31:02.4449-03:00

# %%
import requests
from pprint import pprint
'''
Separamos responsabilidades (buena practica)
- El bot queda como está
- Creamos un archivo nuevo solo para probar precios
'''

# URL de la api a consumir

URL = "https://dolarapi.com/v1/dolares"


def get_dolar():
    response = requests.get(URL, timeout=10)
    response.raise_for_status()
    return response.json()

data = get_dolar()

for item in data:
    if item['casa'] in ['bolsa','cripto']:
        print(
            f'{item['nombre']}:'
            f'compra {item['compra']} | '
            f'venta {item['venta']} | '
            f'fecha {item['fechaActualizacion']}'
        )
# Out:
# Bolsa:compra 1499.5 | venta 1501.5 | fecha 2025-12-16T20:57:00.000Z
# Cripto:compra 1517.37 | venta 1539.59 | fecha 2025-12-16T20:57:00.000Z
